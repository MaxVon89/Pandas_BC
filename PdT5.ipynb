# %% [markdown]
# ## Filtering

# %%
import pandas as pd

d8 = pd.read_csv("D:\\Datasets\\multipleLinearRegression\\CarPrice_Assignment.csv")

# d8s = d8.iloc[:,:]
# d8s

# # d8s = pd.concat(d8, d8['carbody'])
# d8s= pd.concat([d8, d8['carbody']])
# d8s
# Out:
#      car_ID  symboling                   CarName fueltype aspiration  \
# 0       1.0        3.0        alfa-romero giulia      gas        std
# 1       2.0        3.0       alfa-romero stelvio      gas        std
# 2       3.0        1.0  alfa-romero Quadrifoglio      gas        std
# 3       4.0        2.0               audi 100 ls      gas        std
# 4       5.0        2.0                audi 100ls      gas        std
# ..      ...        ...                       ...      ...        ...
# 200     NaN        NaN                       NaN      NaN        NaN
# 201     NaN        NaN                       NaN      NaN        NaN
# 202     NaN        NaN                       NaN      NaN        NaN
# 203     NaN        NaN                       NaN      NaN        NaN
# 204     NaN        NaN                       NaN      NaN        NaN
#
#     doornumber      carbody drivewheel enginelocation  wheelbase  ...  \
# ...

# %%
carBody = str(input(f"Enter the type of body: "))
print(d8[d8['carbody'].str.contains(carBody, case=False)]) #Not working due to NaN vals
print(d8[d8['carbody']==carBody]) #Works, but returns all other fields as NaN, IDK why.

sedans= d8[d8['carbody']=='sedan'] #Again, returns other fields as NaN.
sedans
# Out:
#      car_ID  symboling          CarName fueltype aspiration doornumber  \
# 3         4          2      audi 100 ls      gas        std       four
# 4         5          2       audi 100ls      gas        std       four
# 5         6          2         audi fox      gas        std        two
# 6         7          1       audi 100ls      gas        std       four
# 8         9          1        audi 4000      gas      turbo       four
# ..      ...        ...              ...      ...        ...        ...
# 200     201         -1  volvo 145e (sw)      gas        std       four
# 201     202         -1      volvo 144ea      gas      turbo       four
# 202     203         -1      volvo 244dl      gas        std       four
# 203     204         -1        volvo 246   diesel      turbo       four
# 204     205         -1      volvo 264gl      gas      turbo       four
#
#     carbody drivewheel enginelocation  wheelbase  ...  enginesize  fuelsystem  \
# ...

# %%
# gassGuzzler = d8[d8['citympg']<20.0]

gassGuzzler = d8[(d8['citympg']<20.0) &
                 (d8['enginesize']>150)]
gassGuzzler
gassGuzzler.head()
# Out:
#     car_ID  symboling                    CarName fueltype aspiration  \
# 2        3          1   alfa-romero Quadrifoglio      gas        std
# 15      16          0                     bmw x4      gas        std
# 16      17          0                     bmw x5      gas        std
# 17      18          0                     bmw x3      gas        std
# 29      30          3  dodge coronet custom (sw)      gas      turbo
#
#    doornumber    carbody drivewheel enginelocation  wheelbase  ...  \
# 2         two  hatchback        rwd          front       94.5  ...
# 15       four      sedan        rwd          front      103.5  ...
# 16        two      sedan        rwd          front      103.5  ...
# 17       four      sedan        rwd          front      110.0  ...
# 29        two  hatchback        fwd          front       95.9  ...
#
#     enginesize  fuelsystem  boreratio  stroke compressionratio horsepower  \
# ...
